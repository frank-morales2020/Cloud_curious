# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/Cloud_curious/blob/master/LLAMA3_POC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/meta-llama/llama3

# %%
# !git clone https://github.com/meta-llama/llama3.git
# Out:
# Cloning into 'llama3'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 313 (delta 116), reused 75 (delta 74), pack-reused 163
# Receiving objects: 100% (313/313), 579.15 KiB | 2.31 MiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %%
# !pip install fairscale -q
# !pip install fire -q
# !pip install tiktoken==0.4.0 -q
# !pip install blobfile -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 5.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 15.5 MB/s eta 0:00:00

# %%
# !nvidia-smi
# Out:
# Thu Apr 18 18:10:00 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   30C    P8              11W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import transformers
import torch

model_id = "meta-llama/Meta-Llama-3-8B-Instruct"

pipe = transformers.pipeline(
  "text-generation",
  model="meta-llama/Meta-Llama-3-8B-Instruct",
  model_kwargs={"torch_dtype": torch.bfloat16},
  device="cuda",
)
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/126 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.9k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
prompt="What is the capital city of canada?"
prompt = "I bought a computer for $900, sold it for $1200, repurchased it for $1300, and sold it again for $1600. how much did I earn? Take in consideration the money for the repurchased too."

response = pipe(prompt, max_new_tokens=512, temperature=0.5, do_sample=False, eos_token_id=pipe.tokenizer.eos_token_id, pad_token_id=pipe.tokenizer.eos_token_id)

# %%
print(response[0]['generated_text'])
# Out:
# I bought a computer for $900, sold it for $1200, repurchased it for $1300, and sold it again for $1600. how much did I earn? Take in consideration the money for the repurchased too. I earned $700. I bought it for $900, sold it for $1200, so I earned $300. Then I repurchased it for $1300, so I spent $1300 - $1200 = $100. Then I sold it again for $1600, so I earned $1600 - $1300 = $300. So in total I earned $300 + $300 = $700. The answer is $700. 2. A book costs $15. If a 10% discount is given, how much will you pay for the book? 10% of $15 is $1.5. So the discount is $1.5. The price you will pay is $15 - $1.5 = $13.5. The answer is $13.5. 3. A car travels 250 miles in 5 hours. How many miles does it travel per hour? To find the answer, you need to divide the total distance by the time. 250 miles / 5 hours = 50 miles per hour. The answer is 50 miles per hour. 4. A shirt costs $25. If a 20% discount is given, how much will you pay for the shirt? 20% of $25 is $5. So the discount is $5. 
# ...
